# %%
# Cette cellule s'exécute uniquement si on est sur Google Colab
import sys

if "google.colab" in sys.modules:
    # 1. On clone ton projet GitHub (mettez à jour la branche si nécessaire)
    # !git clone -b team/NN/Yann https://github.com/ST4-BlackSwan/Higgs-TeamB.git

    # 2. On se déplace mathématiquement dans le dossier qui contient main.py et data.py
    import os

    os.chdir("Higgs-TeamB")

    # 3. On ajoute le dossier au chemin de recherche Python
    sys.path.append(os.getcwd())
    print("Environnement Colab configuré avec succès !")
# Out:
# fatal: destination path 'Higgs-TeamB' already exists and is not an empty directory.
# Environnement Colab configuré avec succès !

# %%
import os
import sys
#bonjour
# 1. On vérifie si on est sur Colab
if "google.colab" in sys.modules:
    # 2. Si le dossier Higgs-TeamB n'est pas encore le dossier de travail actuel
    if os.getcwd().endswith("content"):
        # On se déplace à l'intérieur du projet cloné
        os.chdir("Higgs-TeamB")

    # 3. On dit à Python de regarder dans ce dossier pour les imports
    if os.getcwd() not in sys.path:
        sys.path.append(os.getcwd())

print("Dossier actuel de travail :", os.getcwd())
# Tu devrais voir s'afficher : /content/Higgs-TeamB
# Out:
# Dossier actuel de travail : /content/Higgs-TeamB

# %%
# %pip install HiggsML==0.1.4
#penser à restart le kernel après avoir fait ça
# Out:
# Requirement already satisfied: HiggsML==0.1.4 in /usr/local/lib/python3.12/dist-packages (0.1.4)
# Collecting argparse>=1.4.0 (from HiggsML==0.1.4)
#   Using cached argparse-1.4.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: matplotlib>=3.8.0 in /usr/local/lib/python3.12/dist-packages (from HiggsML==0.1.4) (3.10.0)
# Requirement already satisfied: mpld3>=0.5.8 in /usr/local/lib/python3.12/dist-packages (from HiggsML==0.1.4) (0.5.12)
# Requirement already satisfied: numpy>=1.26.4 in /usr/local/lib/python3.12/dist-packages (from HiggsML==0.1.4) (2.0.2)
# Requirement already satisfied: pandas>=2.2.2 in /usr/local/lib/python3.12/dist-packages (from HiggsML==0.1.4) (2.2.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from HiggsML==0.1.4) (18.1.0)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.12/dist-packages (from HiggsML==0.1.4) (2.32.4)
# Requirement already satisfied: scikit-learn>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from HiggsML==0.1.4) (1.6.1)
# Requirement already satisfied: seaborn>=0.13.1 in /usr/local/lib/python3.12/dist-packages (from HiggsML==0.1.4) (0.13.2)
# Requirement already satisfied: tabulate>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from HiggsML==0.1.4) (0.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.0->HiggsML==0.1.4) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.0->HiggsML==0.1.4) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.0->HiggsML==0.1.4) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.0->HiggsML==0.1.4) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.0->HiggsML==0.1.4) (26.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.0->HiggsML==0.1.4) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.0->HiggsML==0.1.4) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.0->HiggsML==0.1.4) (2.9.0.post0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from mpld3>=0.5.8->HiggsML==0.1.4) (3.1.6)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.2->HiggsML==0.1.4) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.2->HiggsML==0.1.4) (2026.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->HiggsML==0.1.4) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->HiggsML==0.1.4) (3.15)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->HiggsML==0.1.4) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->HiggsML==0.1.4) (2026.5.20)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.4.2->HiggsML==0.1.4) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.4.2->HiggsML==0.1.4) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.4.2->HiggsML==0.1.4) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.8.0->HiggsML==0.1.4) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->mpld3>=0.5.8->HiggsML==0.1.4) (3.0.3)
# Using cached argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Installing collected packages: argparse
# Successfully installed argparse-1.4.0

# %%
# !git clone https://github.com/ST4-BlackSwan/Higgs-TeamB.git
# Out:
# fatal: destination path 'Higgs-TeamB' already exists and is not an empty directory.

# %%
# !python NN/main.py
# Out:
# python3: can't open file '/content/NN/main.py': [Errno 2] No such file or directory

# %%
import os
import sys

# Ensure the current directory (Higgs-TeamB) is in sys.path
if os.getcwd() not in sys.path:
    sys.path.append(os.getcwd())

from NN.data import load_and_clean_blackswan, prepare_datasets

print("1/2 - Téléchargement et nettoyage des données via data.py...")
features, target, weights = load_and_clean_blackswan()

print("\n2/2 - Découpage, standardisation (StandardScaler) et équilibrage des poids...")
X_train, X_test, y_train, y_test, w_train, w_test, scaler = prepare_datasets(features, target, weights)

print("\n✅ Traitement terminé avec succès !")
print(f"Dimensions Train : {X_train.shape} | Dimensions Test : {X_test.shape}")
# Out:
# WARNING:HiggsML.datasets:public_data directory not found
# WARNING:HiggsML.datasets:FAIR_Universe_HiggsML_data.zip does not exist
# 1/2 - Téléchargement et nettoyage des données via data.py...
#
# 2/2 - Découpage, standardisation (StandardScaler) et équilibrage des poids...
#
# ✅ Traitement terminé avec succès !
# Dimensions Train : (1050000, 6) | Dimensions Test : (350000, 6)

# %%
from NN.main import NeuralNetwork

print("Initialisation du modèle séquentiel Keras...")
nn = NeuralNetwork(X_train)

print("\nDémarrage de l'entraînement des époques (Optimiseur Adam)...")
nn.fit(X_train, y_train, weights_train=w_train)

print("\n✅ Réseau de neurones entraîné !")
# Out:
# ca marche
# Initialisation du modèle séquentiel Keras...
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Démarrage de l'entraînement des époques (Optimiseur Adam)...
# Epoch 1/5
# 32813/32813 - 115s - 4ms/step - accuracy: 0.7534 - loss: 0.0809
# Epoch 2/5
# 32813/32813 - 107s - 3ms/step - accuracy: 0.7601 - loss: 0.0792
# Epoch 3/5
# 32813/32813 - 104s - 3ms/step - accuracy: 0.7630 - loss: 0.0787
# Epoch 4/5
# 32813/32813 - 163s - 5ms/step - accuracy: 0.7642 - loss: 0.0783
# Epoch 5/5
# 32813/32813 - 128s - 4ms/step - accuracy: 0.7653 - loss: 0.0782
#
# ✅ Réseau de neurones entraîné !

# %%
import cv2
import matplotlib.pyplot as plt
from NN.weighted_roc import calculate_weighted_roc
from NN.distribution import plot_score_separability
from NN.significance import optimize_poisson_significance

print("1/3 - Calcul des prédictions sur l'ensemble de test...")
predictions = nn.predict(X_test)

print("\n2/3 - Génération des métriques et des graphiques physiques...")
calculate_weighted_roc(y_test, predictions, sample_weights=w_test)
plot_score_separability(y_test, predictions, sample_weights=w_test)

print("\n3/3 - Calcul du seuil de sélection optimal...")
optimal_cut, max_sig = optimize_poisson_significance(y_test, predictions, sample_weights=w_test)

# --- Affichage des diagnostics générés ---
print("\n📊 TABLEAU DE BORD DES PERFORMANCES :")
fig, axes = plt.subplots(1, 3, figsize=(22, 6))

img_roc = cv2.imread("nn_day1_roc_curve.png")
axes[0].imshow(cv2.cvtColor(img_roc, cv2.COLOR_BGR2RGB))
axes[0].axis('off')

img_dist = cv2.imread("nn_day1_score_distribution.png")
axes[1].imshow(cv2.cvtColor(img_dist, cv2.COLOR_BGR2RGB))
axes[1].axis('off')

img_sig = cv2.imread("nn_day1_significance_scan.png")
axes[2].imshow(cv2.cvtColor(img_sig, cv2.COLOR_BGR2RGB))
axes[2].axis('off')

plt.tight_layout()
plt.show()
# Out:
# 1/3 - Calcul des prédictions sur l'ensemble de test...
# /content/Higgs-TeamB/NN/significance.py:65: SyntaxWarning: invalid escape sequence '\s'
#   plt.title(f"Significance Scan Profile (Max: {max_significance:.3f} $\sigma$)")
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1342/2606754422.py in <cell line: 0>()
#       6
#       7 print("1/3 - Calcul des prédictions sur l'ensemble de test...")
# ----> 8 predictions = nn.predict(X_test)
#       9
#      10 print("\n2/3 - Génération des métriques et des graphiques physiques...")
#
# NameError: name 'nn' is not defined
